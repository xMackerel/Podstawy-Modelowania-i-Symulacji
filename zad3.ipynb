# %%
import matplotlib.pyplot as plt
import numpy as np

R=1000;
NN = 961/500;
C=1/(NN*R)
a=1/(R*C)
w=2
A=300/R
c=0

ww=np.linspace(0.01, 0.2, )
ss = []
ssd = []
s = A*(a*np.sin(w*t)-w*np.cos(w*t))
sd = A*(a*w*np.cos(w*t)+w*w*np.sin(w*t))/(w**2+a**2)

t=np.linspace()

fig,ax=plt.subplots()
ax.plot(t,s,t,sd)
#ax.plot(ww,ss,ww,ssd)
plt.legend(['C', 'R'])
plt.show()

# %%
R,c,a
# Out:
# (1000, 0, 1.9219999999999997)

# %%
max(s), min(s)
# Out:
# (0.8321454237208473, -0.8321125877637797)
